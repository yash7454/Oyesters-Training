# %% [markdown]
# <a href="https://colab.research.google.com/github/yash7454/Oyesters-Training/blob/master/Day_3_Questions_Assignment_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# www.youtube.com/diazoniclabs

# %% [markdown]
# # Assignment - Day 3:
# Hope that by now, everyone would have had Github account and LinkedIn account.
# 1. Technical Assignment of 6 simple questions is posted as follows.
#
# 2. Write a small post on your LinkedIn wall of today's class and tag us with
#
#  #diazoniclabswebinar
#
#  @OyestersTraining
#
#  @Diazonic Labs
#
# Sample Post: https://www.linkedin.com/posts/rohithkalvakota_str-f-workshop-activity-6666963613699465216-1tqj

# %% [markdown]
# **Welcome to your Assessment 3! Complete the tasks described below by typing the relevant code in the cells. The output is given for your reference after the questions. You will get different answers because of dealing with random values**

# %% [markdown]
# #Write a Program to plot a graph for an analysis of a cricket match . Over a period of 20 overs starting from 2nd over to 20th over, the visualisation graph has to be created for Team1 as well as Team2

# %% [markdown]
# Open this link for reference photo : https://drive.google.com/uc?id=1StZcX-ip1K9MwufhBgAT62OtZYpNMcDN

# %% [markdown]
# ## 1. Take a variable named overs and assign the value by creating a numpy array using arange function from value 2 to 21 keeping 3 as the step

# %%
import numpy as np
overs = np.arange(2,21,3)
print(overs)
print(overs.shape)
# Out:
# [ 2  5  8 11 14 17 20]
# (7,)

# %% [markdown]
# ##2.Create 2 random numpy arrays taking values from 0 to 150 and store it in  2 variables named team1 and team2 respectively.Sort the values of both team1 and team2 variables
# Hint: For the number of values in each array, please refer question 1 . The total number of batches taken for overs should be same as values taken for Variables team1 and team2

# %%
team1 = np.sort(np.random.randint(0,150,7))
team2 = np.sort(np.random.randint(0,150,7))
print(team1)
print(team2)
# Out:
# [ 27  57  87  93 106 117 133]
# [  6  35  67  72  79 116 143]

# %% [markdown]
# ## 3. Plot a Line Plot along with marker for both the teams taking overs on X axis and Score on Y axis.

# %%
import matplotlib.pyplot as plt
plt.plot(overs,team1,marker = '*')
plt.plot(overs,team2,marker = '+')
ax = plt.axes()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %% [markdown]
# #4. Label X - axis as Overs and Y- Axis as Score. Also, give the title of graph as Cricket Match Analysis. Give different colors for both the teams graphs

# %%
plt.plot(overs,team1,c ='lightblue',marker = '*')
plt.plot(overs,team2,c ='orange',marker = '+')
ax = plt.axes()
plt.xlabel('Overs')
plt.ylabel('Score')
plt.title('Cricket Match Analysis')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # 5. Put a legend label for differentiating both the teams graph
#
# ###Hint: Please use an extra parameter called as labels in plot method and call for plt.legend() at the end.
# ###The box which is on top left side of the graph labeled as Team 1 and Team 2 with Red and Green colors is the legend of the graph
#
#
# ###Refer the link for reference plot: https://drive.google.com/uc?id=1StZcX-ip1K9MwufhBgAT62OtZYpNMcDN

# %%
plt.plot(overs,team1,c ='lightblue',marker = '*')
plt.plot(overs,team2,c ='orange',marker = '+', )
ax = plt.axes()
ax.set_facecolor('w')
plt.legend(["Team1","Team2"])
plt.xlabel('Overs')
plt.ylabel('Score')
plt.title('Cricket Match Analysis')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # 6. Pie Chart
# Create a list named mobile_count which contains 5 random values from range of 0 to 100.
# Use for loop and random library
#
# Use a variable named mobile _model as Apple,Samsung,Vivo,Nokia and Huawei
#
# Plot a Pie chart for mobile_count variable and consider mobile _model as a label parameter

# %%
mobile_count = np.random.randint(0,100,5)
mobile_model = ["Apple", "Samsung", "Vivo", "Nokia", "Huawei"]
print(mobile_count, mobile_model)
# Out:
# [ 6 96 28 88 86] ['Apple', 'Samsung', 'Vivo', 'Nokia', 'Huawei']

# %%
plt.pie(mobile_count, labels=mobile_model)
plt.show()
